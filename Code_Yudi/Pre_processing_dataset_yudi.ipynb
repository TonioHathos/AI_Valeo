# %% [markdown]
# <a href="https://colab.research.google.com/github/TonioHathos/AI_Valeo/blob/main/Code_Yudi/Pre_processing_dataset_yudi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avant Première presentation

# %%
import pandas as pd # For dataframes (tables)
import numpy as np # For numerical operations
import math 
import matplotlib.pyplot as plt # For plots
import os # To import external python files
import sys# To import external python files
import missingno as msno

from pandas.plotting import scatter_matrix

# %% [markdown]
# Télechargement du dataset

# %%
! rm -f *.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/testinputs.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/traininginputs.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/trainingoutput.csv
# Out:
# --2023-05-26 09:40:15--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/testinputs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795776 (777K) [text/plain]
# Saving to: ‘testinputs.csv’
#
# testinputs.csv      100%[===================>] 777.12K  --.-KB/s    in 0.03s
#
# 2023-05-26 09:40:15 (26.1 MB/s) - ‘testinputs.csv’ saved [795776/795776]
#
# --2023-05-26 09:40:15--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/traininginputs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3432084 (3.3M) [text/plain]
# Saving to: ‘traininginputs.csv’
#
# traininginputs.csv  100%[===================>]   3.27M  --.-KB/s    in 0.04s
#
# 2023-05-26 09:40:16 (79.5 MB/s) - ‘traininginputs.csv’ saved [3432084/3432084]
#
# --2023-05-26 09:40:16--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/trainingoutput.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1000980 (978K) [text/plain]
# Saving to: ‘trainingoutput.csv’
#
# trainingoutput.csv  100%[===================>] 977.52K  --.-KB/s    in 0.03s
#
# 2023-05-26 09:40:16 (28.3 MB/s) - ‘trainingoutput.csv’ saved [1000980/1000980]

# %%
# !ls
# Out:
# sample_data  testinputs.csv  traininginputs.csv  trainingoutput.csv

# %%
df_test_inputs = pd.read_csv('testinputs.csv')
df_training_inputs = pd.read_csv('traininginputs.csv')
df_training_output = pd.read_csv('trainingoutput.csv')

# %% [markdown]
# **Training Inputs**

# %%
df_training_inputs.shape
# Out:
# (34515, 14)

# %% [markdown]
# Changement des noms

# %%
df_training_inputs.rename(columns={'OP120_Rodage_U_mesure_value': 'Rodage_U','OP120_Rodage_I_mesure_value': 'Rodage_I','OP070_V_1_angle_value': 'Premier angle','OP070_V_2_torque_value': 'V2_torque','OP090_SnapRingMidPointForce_val': 'SnapRingMidPointForce','OP110_Vissage_M8_angle_value': 'Vissage_M8_angle','OP090_StartLinePeakForce_value': 'StartLinePeakForce','OP070_V_1_torque_value': 'V1_torque','OP100_Capuchon_insertion_mesure': 'Capuchon_insertion','OP110_Vissage_M8_torque_value': 'Vissage_M8_torque','OP090_SnapRingFinalStroke_value': 'SnapRingFinalStroke','OP090_SnapRingPeakForce_value': 'SnapRingPeakForce','OP070_V_2_angle_value': 'Deuxième angle'}, inplace=True)

# %%
df_training_inputs.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34515 entries, 0 to 34514
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PROC_TRACEINFO         34515 non-null  object
#  1   Premier angle          34515 non-null  float64
#  2   SnapRingPeakForce      34515 non-null  float64
#  3   Deuxième angle         34515 non-null  float64
#  4   Rodage_I               34515 non-null  float64
#  5   SnapRingFinalStroke    34515 non-null  float64
#  6   Vissage_M8_torque      34515 non-null  float64
#  7   Capuchon_insertion     15888 non-null  float64
#  8   Rodage_U               34515 non-null  float64
#  9   V1_torque              34515 non-null  float64
#  10  StartLinePeakForce     34515 non-null  float64
#  11  Vissage_M8_angle       34515 non-null  float64
#  12  SnapRingMidPointForce  34515 non-null  float64
#  13  V2_torque              34515 non-null  float64
# dtypes: float64(13), object(1)
# memory usage: 3.7+ MB

# %%
with pd.option_context('display.max_columns', df_training_inputs.shape[1]):
    print(df_training_inputs.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  Premier angle  SnapRingPeakForce  \
# count                        34515   34515.000000       34515.000000
# unique                       34515            NaN                NaN
# top     I-B-XA1207672-190429-00688            NaN                NaN
# freq                             1            NaN                NaN
# mean                           NaN     159.906922         156.915055
# std                            NaN      15.662650          11.271492
# min                            NaN     101.800000           0.000000
# 25%                            NaN     148.700000         149.210000
# 50%                            NaN     158.000000         156.180000
# 75%                            NaN     169.300000         164.380000
# max                            NaN     198.300000         196.920000
#
#         Deuxième angle      Rodage_I  SnapRingFinalStroke  Vissage_M8_torque  \
# count     34515.000000  34515.000000         34515.000000       34515.000000
# unique             NaN           NaN                  NaN                NaN
# top                NaN           NaN                  NaN                NaN
# freq               NaN           NaN                  NaN                NaN
# mean        159.618236    113.350222            11.970190          12.256785
# std          15.091490      3.528522             0.169873           0.065319
# min          82.000000     99.990000             0.000000          12.030000
# 25%         149.400000    111.040000            11.850000          12.210000
# 50%         158.700000    113.160000            12.040000          12.260000
# 75%         168.900000    115.380000            12.080000          12.300000
# max         198.100000    177.950000            12.190000          12.500000
#
#         Capuchon_insertion      Rodage_U     V1_torque  StartLinePeakForce  \
# count         15888.000000  34515.000000  34515.000000        34515.000000
# unique                 NaN           NaN           NaN                 NaN
# top                    NaN           NaN           NaN                 NaN
# freq                   NaN           NaN           NaN                 NaN
# mean              0.388173     11.971027      6.548403           23.630152
# std               0.024425      0.003050      0.097602            2.546341
# min               0.240000     11.970000      5.670000            0.000000
# 25%               0.380000     11.970000      6.410000           22.280000
# 50%               0.390000     11.970000      6.610000           23.880000
# 75%               0.410000     11.970000      6.620000           25.290000
# max               0.420000     11.990000      6.670000           43.410000
#
#         Vissage_M8_angle  SnapRingMidPointForce     V2_torque
# count       34515.000000           34515.000000  34515.000000
# unique               NaN                    NaN           NaN
# top                  NaN                    NaN           NaN
# freq                 NaN                    NaN           NaN
# mean           17.878398              97.700978      6.550867
# std             6.785079               6.837714      0.094814
# min             6.300000               0.000000      5.740000
# 25%            13.500000              94.310000      6.420000
# 50%            16.400000              98.500000      6.610000
# 75%            20.200000             102.230000      6.610000
# max            84.600000             127.300000      6.670000

# %% [markdown]
# **Test Inputs**

# %%
df_test_inputs.shape
# Out:
# (8001, 14)

# %%
df_test_inputs_cleaned = df_test_inputs.drop(columns=["PROC_TRACEINFO"])

# %%
df_test_inputs.rename(columns={'OP120_Rodage_U_mesure_value': 'Rodage_U','OP120_Rodage_I_mesure_value': 'Rodage_I','OP070_V_1_angle_value': 'Premier angle','OP070_V_2_torque_value': 'V2_torque','OP090_SnapRingMidPointForce_val': 'SnapRingMidPointForce','OP110_Vissage_M8_angle_value': 'Vissage_M8_angle','OP090_StartLinePeakForce_value': 'StartLinePeakForce','OP070_V_1_torque_value': 'V1_torque','OP100_Capuchon_insertion_mesure': 'Capuchon_insertion','OP110_Vissage_M8_torque_value': 'Vissage_M8_torque','OP090_SnapRingFinalStroke_value': 'SnapRingFinalStroke','OP090_SnapRingPeakForce_value': 'SnapRingPeakForce','OP070_V_2_angle_value': 'Deuxième angle'}, inplace=True)

# %%
df_test_inputs.describe()
# Out:
#        Premier angle  SnapRingPeakForce  Deuxième angle     Rodage_I  \
# count    8001.000000        8001.000000     8001.000000  8001.000000
# mean      159.849919         156.836130      159.678965   113.379749
# std        15.624188          11.683895       15.238943     3.547692
# min       101.900000           0.000000      103.500000   102.420000
# 25%       148.500000         148.970000      149.500000   111.090000
# 50%       158.000000         156.220000      158.700000   113.200000
# 75%       169.100000         164.490000      168.900000   115.370000
# max       198.200000         191.340000      198.000000   186.310000
#
#        SnapRingFinalStroke  Vissage_M8_torque  Capuchon_insertion  \
# count          8001.000000        8001.000000         3641.000000
# mean             11.968191          12.254094            0.388753
# std               0.266558           0.145903            0.024336
# min               0.000000           0.570000            0.250000
# 25%              11.850000          12.210000            0.380000
# 50%              12.040000          12.250000            0.390000
# 75%              12.080000          12.300000            0.410000
# max              12.150000          12.500000            0.420000
#
#           Rodage_U    V1_torque  StartLinePeakForce  Vissage_M8_angle  \
# count  8001.000000  8001.000000          8001.00000       8001.000000
# mean     11.971056     6.548061            23.58853         17.929671
# std       0.003082     0.097780             2.57426          6.709905
# min      11.970000     5.810000             0.00000          0.000000
# 25%      11.970000     6.410000            22.23000         13.600000
# 50%      11.970000     6.610000            23.82000         16.500000
# 75%      11.970000     6.620000            25.24000         20.200000
# max      11.990000     6.660000            36.43000         72.600000
#
#        SnapRingMidPointForce    V2_torque
# count            8001.000000  8001.000000
# mean               97.607625     6.549979
# std                 7.023431     0.095063
# min                 0.000000     5.900000
# 25%                94.290000     6.420000
# 50%                98.410000     6.610000
# 75%               102.230000     6.610000
# max               133.550000     6.680000

# %%
df_test_inputs.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8001 entries, 0 to 8000
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PROC_TRACEINFO         8001 non-null   object
#  1   Premier angle          8001 non-null   float64
#  2   SnapRingPeakForce      8001 non-null   float64
#  3   Deuxième angle         8001 non-null   float64
#  4   Rodage_I               8001 non-null   float64
#  5   SnapRingFinalStroke    8001 non-null   float64
#  6   Vissage_M8_torque      8001 non-null   float64
#  7   Capuchon_insertion     3641 non-null   float64
#  8   Rodage_U               8001 non-null   float64
#  9   V1_torque              8001 non-null   float64
#  10  StartLinePeakForce     8001 non-null   float64
#  11  Vissage_M8_angle       8001 non-null   float64
#  12  SnapRingMidPointForce  8001 non-null   float64
#  13  V2_torque              8001 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 875.2+ KB

# %%
with pd.option_context('display.max_columns', df_test_inputs.shape[1]):
    print(df_test_inputs.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  Premier angle  SnapRingPeakForce  \
# count                         8001    8001.000000        8001.000000
# unique                        8001            NaN                NaN
# top     I-B-XA1207672-190520-00632            NaN                NaN
# freq                             1            NaN                NaN
# mean                           NaN     159.849919         156.836130
# std                            NaN      15.624188          11.683895
# min                            NaN     101.900000           0.000000
# 25%                            NaN     148.500000         148.970000
# 50%                            NaN     158.000000         156.220000
# 75%                            NaN     169.100000         164.490000
# max                            NaN     198.200000         191.340000
#
#         Deuxième angle     Rodage_I  SnapRingFinalStroke  Vissage_M8_torque  \
# count      8001.000000  8001.000000          8001.000000        8001.000000
# unique             NaN          NaN                  NaN                NaN
# top                NaN          NaN                  NaN                NaN
# freq               NaN          NaN                  NaN                NaN
# mean        159.678965   113.379749            11.968191          12.254094
# std          15.238943     3.547692             0.266558           0.145903
# min         103.500000   102.420000             0.000000           0.570000
# 25%         149.500000   111.090000            11.850000          12.210000
# 50%         158.700000   113.200000            12.040000          12.250000
# 75%         168.900000   115.370000            12.080000          12.300000
# max         198.000000   186.310000            12.150000          12.500000
#
#         Capuchon_insertion     Rodage_U    V1_torque  StartLinePeakForce  \
# count          3641.000000  8001.000000  8001.000000          8001.00000
# unique                 NaN          NaN          NaN                 NaN
# top                    NaN          NaN          NaN                 NaN
# freq                   NaN          NaN          NaN                 NaN
# mean              0.388753    11.971056     6.548061            23.58853
# std               0.024336     0.003082     0.097780             2.57426
# min               0.250000    11.970000     5.810000             0.00000
# 25%               0.380000    11.970000     6.410000            22.23000
# 50%               0.390000    11.970000     6.610000            23.82000
# 75%               0.410000    11.970000     6.620000            25.24000
# max               0.420000    11.990000     6.660000            36.43000
#
#         Vissage_M8_angle  SnapRingMidPointForce    V2_torque
# count        8001.000000            8001.000000  8001.000000
# unique               NaN                    NaN          NaN
# top                  NaN                    NaN          NaN
# freq                 NaN                    NaN          NaN
# mean           17.929671              97.607625     6.549979
# std             6.709905               7.023431     0.095063
# min             0.000000               0.000000     5.900000
# 25%            13.600000              94.290000     6.420000
# 50%            16.500000              98.410000     6.610000
# 75%            20.200000             102.230000     6.610000
# max            72.600000             133.550000     6.680000

# %% [markdown]
# **Training output**

# %%
df_training_output.shape
# Out:
# (34515, 2)

# %%
df_training_output.describe()
# Out:
#        Binar OP130_Resultat_Global_v
# count                   34515.000000
# mean                        0.008837
# std                         0.093589
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         1.000000

# %%
df_training_output.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34515 entries, 0 to 34514
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PROC_TRACEINFO                 34515 non-null  object
#  1   Binar OP130_Resultat_Global_v  34515 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 539.4+ KB

# %%
with pd.option_context('display.max_columns', df_training_output.shape[1]):
    print(df_training_output.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  Binar OP130_Resultat_Global_v
# count                        34515                   34515.000000
# unique                       34515                            NaN
# top     I-B-XA1207672-190429-00688                            NaN
# freq                             1                            NaN
# mean                           NaN                       0.008837
# std                            NaN                       0.093589
# min                            NaN                       0.000000
# 25%                            NaN                       0.000000
# 50%                            NaN                       0.000000
# 75%                            NaN                       0.000000
# max                            NaN                       1.000000

# %% [markdown]
# **Histograme de chaqu'un**

# %% [markdown]
# Histogram Training input

# %%
df_training_inputs.hist(layout = (4 , 4), figsize = (40,40))
# Out:
# array([[<Axes: title={'center': 'Premier angle'}>,
#         <Axes: title={'center': 'SnapRingPeakForce'}>,
#         <Axes: title={'center': 'Deuxième angle'}>,
#         <Axes: title={'center': 'Rodage_I'}>],
#        [<Axes: title={'center': 'SnapRingFinalStroke'}>,
#         <Axes: title={'center': 'Vissage_M8_torque'}>,
#         <Axes: title={'center': 'Capuchon_insertion'}>,
#         <Axes: title={'center': 'Rodage_U'}>],
#        [<Axes: title={'center': 'V1_torque'}>,
#         <Axes: title={'center': 'StartLinePeakForce'}>,
#         <Axes: title={'center': 'Vissage_M8_angle'}>,
#         <Axes: title={'center': 'SnapRingMidPointForce'}>],
#        [<Axes: title={'center': 'V2_torque'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# Histogram Test Input

# %%
df_test_inputs.hist(layout = (4, 4), figsize = (40,40))
# Out:
# array([[<Axes: title={'center': 'Premier angle'}>,
#         <Axes: title={'center': 'SnapRingPeakForce'}>,
#         <Axes: title={'center': 'Deuxième angle'}>,
#         <Axes: title={'center': 'Rodage_I'}>],
#        [<Axes: title={'center': 'SnapRingFinalStroke'}>,
#         <Axes: title={'center': 'Vissage_M8_torque'}>,
#         <Axes: title={'center': 'Capuchon_insertion'}>,
#         <Axes: title={'center': 'Rodage_U'}>],
#        [<Axes: title={'center': 'V1_torque'}>,
#         <Axes: title={'center': 'StartLinePeakForce'}>,
#         <Axes: title={'center': 'Vissage_M8_angle'}>,
#         <Axes: title={'center': 'SnapRingMidPointForce'}>],
#        [<Axes: title={'center': 'V2_torque'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# Histogram Training outputs

# %%
df_training_output.hist(layout = (4, 4), figsize = (20,20))
# Out:
# array([[<Axes: title={'center': 'Binar OP130_Resultat_Global_v'}>,
#         <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# **BoxPlot**

# %% [markdown]
# Training Inputs

# %%
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
import visualization
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
import feature_engineering
# Out:
# --2023-05-26 09:40:39--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13023 (13K) [text/plain]
# Saving to: ‘visualization.py’
#
# visualization.py    100%[===================>]  12.72K  --.-KB/s    in 0s
#
# 2023-05-26 09:40:39 (63.9 MB/s) - ‘visualization.py’ saved [13023/13023]
#
# --2023-05-26 09:40:40--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2206 (2.2K) [text/plain]
# Saving to: ‘feature_engineering.py’
#
# feature_engineering 100%[===================>]   2.15K  --.-KB/s    in 0s
#
# 2023-05-26 09:40:40 (28.2 MB/s) - ‘feature_engineering.py’ saved [2206/2206]

# %%
bp = df_training_inputs.boxplot()

# %%
ax = df_test_inputs.boxplot()
#visualization.rotate_labels(ax)
plt.show()

# %% [markdown]
# Scaling features

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = df_test_inputs_cleaned.values
X_scaled = scaler.fit_transform(X)
df_scaled = pd.DataFrame(X_scaled)
bp = df_scaled.boxplot()
bp.tick_params(axis='x', labelrotation=45)

# %% [markdown]
# Scatter Matrix

# %% [markdown]
# **Definition des columns qui ont necessité de transformation**

# %%
cols_change = ['Vissage_M8_angle','SnapRingFinalStroke']
#df_training_inputs

# %% [markdown]
# Columns qui n'ont rien changé

# %%
cols_Nchange = ['Rodage_U', 'V1_torque','Rodage_I','V2_torque','SnapRingMidPointForce', 'Premier angle', 'SnapRingPeakForce','Deuxième angle', 'Vissage_M8_torque','Capuchon_insertion','StartLinePeakForce']
#df_training_inputs

# %% [markdown]
# Definition des changements

# %%
cols_to_transform = ['Vissage_M8_angle'];

cols_transformed = [s + "_log" for s in cols_to_transform]
df_training_inputs[cols_transformed] = df_training_inputs[cols_to_transform].transform(
                        func=lambda x : np.log(x))

# %%
cols_to_transform1 = ['SnapRingFinalStroke']
cols_transformed1 = [s + "_exp" for s in cols_to_transform1]

df_training_inputs[cols_transformed1] = df_training_inputs[cols_to_transform1].transform(
    func=lambda x: np.exp(1+x))

# %% [markdown]
# Definition des columns dejà changé

# %%
cols_change_transf = cols_transformed + cols_transformed1
#df_training_inputs[cols_change_transf]

# %%
cols_to_plot = cols_Nchange + cols_change_transf
#df_training_inputs[columns_to_plot]
cols_to_plot
# Out:
# ['Rodage_U',
#  'V1_torque',
#  'Rodage_I',
#  'V2_torque',
#  'SnapRingMidPointForce',
#  'Premier angle',
#  'SnapRingPeakForce',
#  'Deuxième angle',
#  'Vissage_M8_torque',
#  'Capuchon_insertion',
#  'StartLinePeakForce',
#  'Vissage_M8_angle_log',
#  'SnapRingFinalStroke_exp']

# %%
sm = scatter_matrix(df_training_inputs[cols_to_plot], figsize=(10, 10), alpha = 0.5, color = 'red')

visualization.rotate_labels(sm)
plt.show()

# %% [markdown]
# Amellioration de la visu

# %% [markdown]
# Visualization de caracteristique à changer

# %%
sm = scatter_matrix(df_training_inputs[cols_change],
                   figsize=(10,10), color = 'red')
visualization.rotate_labels(sm)
plt.show()

# %% [markdown]
# Sm des paramètres changés

# %%
sm = scatter_matrix(df_training_inputs[cols_change_transf],
                   figsize=(10,10), color='red')

visualization.rotate_labels(sm)
plt.show()

# %%
feature_engineering.get_features_correlated_to_target(df_training_inputs,
                                    target_feature='Premier angle').head(10)
# Out:
# /content/feature_engineering.py:79: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmatrix = df.corr().round(2)
# Premier angle              1.00
# Deuxième angle             0.19
# SnapRingFinalStroke_exp   -0.11
# SnapRingFinalStroke       -0.09
# SnapRingMidPointForce      0.07
# V2_torque                  0.07
# StartLinePeakForce         0.06
# Rodage_I                   0.04
# Vissage_M8_torque         -0.02
# Capuchon_insertion        -0.02
# Name: Premier angle, dtype: float64

# %% [markdown]
# Tentativa inútil

# %%
df_training_inputs[cols_change].hist(bins=50, figsize = (10,5))
plt.show()

df_training_inputs[cols_change_transf].hist(bins=50, figsize = (10,5))
plt.show()

# %% [markdown]
# # Modifier le dataset

# %% [markdown]
# Modification des NAN pour 0 et les valeurs presents pour 1

# %%
df_training_inputs['Capuchon_insertion'] = df_training_inputs['Capuchon_insertion'].fillna(0)

# Substitua os valores não nulos por 1
df_training_inputs['Capuchon_insertion'] = df_training_inputs['Capuchon_insertion'].apply(lambda x: 1 if x != 0 else x)

# %% [markdown]
# Suppression de la colonne PROC_TRACEINFO

# %%
df_training_inputs = pd.merge(df_training_inputs, df_training_output, on='PROC_TRACEINFO')
df_training_inputs = df_training_inputs.drop(columns=["PROC_TRACEINFO"])

# %%
df_training_output.describe()
# Out:
#        Binar OP130_Resultat_Global_v
# count                   34515.000000
# mean                        0.008837
# std                         0.093589
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         1.000000

# %% [markdown]
# Groupe des toute les colonnes d'interrêt

# %%
cols_to_plot2 = cols_to_plot + ['Binar OP130_Resultat_Global_v']

# %% [markdown]
# Visu sur les colonnes changées

# %%
df_training_inputs[cols_change + cols_change_transf].describe()
# Out:
#        Vissage_M8_angle  SnapRingFinalStroke  Vissage_M8_angle_log  \
# count      34515.000000         34515.000000          34515.000000
# mean          17.878398            11.970190              2.826255
# std            6.785079             0.169873              0.325871
# min            6.300000             0.000000              1.840550
# 25%           13.500000            11.850000              2.602690
# 50%           16.400000            12.040000              2.797281
# 75%           20.200000            12.080000              3.005683
# max           84.600000            12.190000              4.437934
#
#        SnapRingFinalStroke_exp
# count             34515.000000
# mean             433255.325067
# std               53512.641384
# min                   2.718282
# 25%              380788.735379
# 50%              460468.625050
# 75%              479260.706129
# max              534988.216285

# %%
msno.matrix(df_training_inputs)
# Out:
# <Axes: >

# %% [markdown]
# Modifications sur V1 et V2 torque

# %%
df_training_inputs[['V1_torque', 'V2_torque']].hist(bins=50, figsize = (10,5))
plt.show()

ax = df_training_inputs[['V1_torque', 'V2_torque']].boxplot()
ax.tick_params(axis='x', labelrotation=45)

# %%
df_training_inputs[['V1_torque']].value_counts()
# Out:
# V1_torque
# 6.61         8445
# 6.62         7987
# 6.41         5992
# 6.60         4987
# 6.40         2554
#              ...
# 6.06            1
# 5.95            1
# 5.86            1
# 5.84            1
# 6.67            1
# Length: 70, dtype: int64

# %%
df_training_inputs['V1_torque'] = np.where(df_training_inputs['V1_torque'] <= 6.5, 0, 1)

df_training_inputs[['V1_torque']].value_counts()
# Out:
# V1_torque
# 1            23768
# 0            10747
# dtype: int64

# %%
df_training_inputs[['V2_torque']].value_counts()
# Out:
# V2_torque
# 6.61         11265
# 6.41          5160
# 6.60          4731
# 6.62          3813
# 6.63          3102
#              ...
# 6.08             1
# 6.09             1
# 6.17             1
# 6.18             1
# 5.74             1
# Length: 64, dtype: int64

# %%
df_training_inputs['V2_torque'] = np.where(df_training_inputs['V2_torque'] <= 6.5, 0, 1)

df_training_inputs[['V2_torque']].value_counts()
# Out:
# V2_torque
# 1            23935
# 0            10580
# dtype: int64

# %% [markdown]
# Il faut modifier le Rodage_U aussi, car il a juste 3 valeurs

# %%
df_training_inputs[['Rodage_U']].value_counts()
# Out:
# Rodage_U
# 11.97       30983
# 11.98        3518
# 11.99          14
# dtype: int64

# %%
df_training_inputs[['Binar OP130_Resultat_Global_v']].value_counts()
# Out:
# Binar OP130_Resultat_Global_v
# 0                                34210
# 1                                  305
# dtype: int64

# %% [markdown]
# Confirmation des modifications

# %%
sm = scatter_matrix(df_training_inputs[cols_to_plot2],figsize = (15, 10), alpha = 0.5, color = 'red')

visualization.rotate_labels(sm)
plt.show()

# %% [markdown]
# Visu sur Correlation Pearson

# %%
corrmatrix = df_training_inputs.corr()
corrmatrix
# Out:
#                                Premier angle  SnapRingPeakForce  \
# Premier angle                       1.000000           0.008887
# SnapRingPeakForce                   0.008887           1.000000
# Deuxième angle                      0.186781           0.038399
# Rodage_I                            0.035003           0.055235
# SnapRingFinalStroke                -0.087910           0.076451
# Vissage_M8_torque                  -0.017578          -0.134780
# Capuchon_insertion                 -0.086510          -0.518705
# Rodage_U                           -0.007284           0.135288
# V1_torque                           0.029245           0.491583
# StartLinePeakForce                  0.057592           0.336620
# Vissage_M8_angle                    0.014374           0.106753
# SnapRingMidPointForce               0.066924           0.345139
# V2_torque                           0.083662           0.489280
# Vissage_M8_angle_log                0.021449           0.107327
# SnapRingFinalStroke_exp            -0.112748          -0.012354
# Binar OP130_Resultat_Global_v      -0.012793          -0.007290
#
#                                Deuxième angle  Rodage_I  SnapRingFinalStroke  \
# Premier angle                        0.186781  0.035003            -0.087910
# SnapRingPeakForce                    0.038399  0.055235             0.076451
# Deuxième angle                       1.000000  0.036301            -0.060931
# Rodage_I                             0.036301  1.000000             0.060014
# SnapRingFinalStroke                 -0.060931  0.060014             1.000000
# Vissage_M8_torque                   -0.030284 -0.046313            -0.095903
# Capuchon_insertion                  -0.121070 -0.068255             0.131917
# Rodage_U                             0.003245 -0.118751            -0.022536
# V1_torque                            0.071833  0.037032            -0.415244
# StartLinePeakForce                   0.047190  0.002962            -0.381450
# Vissage_M8_angle                     0.017727  0.025043             0.022764
# SnapRingMidPointForce                0.050193  0.046556            -0.081412
# V2_torque                            0.044249  0.038527            -0.425514
# Vissage_M8_angle_log                 0.023336  0.027576             0.031721
# SnapRingFinalStroke_exp             -0.073238  0.076714             0.795896
# Binar OP130_Resultat_Global_v       -0.006342  0.003763             0.015148
#
#                                Vissage_M8_torque  Capuchon_insertion  \
# Premier angle                          -0.017578           -0.086510
# SnapRingPeakForce                      -0.134780           -0.518705
# Deuxième angle                         -0.030284           -0.121070
# Rodage_I                               -0.046313           -0.068255
# SnapRingFinalStroke                    -0.095903            0.131917
# Vissage_M8_torque                       1.000000            0.104997
# Capuchon_insertion                      0.104997            1.000000
# Rodage_U                               -0.031115           -0.189151
# V1_torque                              -0.076199           -0.681892
# StartLinePeakForce                      0.009997           -0.350268
# Vissage_M8_angle                       -0.445953           -0.043183
# SnapRingMidPointForce                  -0.057760           -0.249981
# V2_torque                              -0.074945           -0.689374
# Vissage_M8_angle_log                   -0.515324           -0.043100
# SnapRingFinalStroke_exp                -0.128840            0.188305
# Binar OP130_Resultat_Global_v          -0.002984            0.033914
#
#                                Rodage_U  V1_torque  StartLinePeakForce  \
# Premier angle                 -0.007284   0.029245            0.057592
# SnapRingPeakForce              0.135288   0.491583            0.336620
# Deuxième angle                 0.003245   0.071833            0.047190
# Rodage_I                      -0.118751   0.037032            0.002962
# SnapRingFinalStroke           -0.022536  -0.415244           -0.381450
# Vissage_M8_torque             -0.031115  -0.076199            0.009997
# Capuchon_insertion            -0.189151  -0.681892           -0.350268
# Rodage_U                       1.000000   0.171555            0.087487
# V1_torque                      0.171555   1.000000            0.572020
# StartLinePeakForce             0.087487   0.572020            1.000000
# Vissage_M8_angle               0.013814   0.116466            0.043943
# SnapRingMidPointForce          0.057027   0.350925            0.620728
# V2_torque                      0.175152   0.953855            0.579126
# Vissage_M8_angle_log           0.014373   0.108191            0.037062
# SnapRingFinalStroke_exp       -0.038234  -0.568716           -0.592980
# Binar OP130_Resultat_Global_v -0.010492  -0.039466            0.010720
#
#                                Vissage_M8_angle  SnapRingMidPointForce  \
# Premier angle                          0.014374               0.066924
# SnapRingPeakForce                      0.106753               0.345139
# Deuxième angle                         0.017727               0.050193
# Rodage_I                               0.025043               0.046556
# SnapRingFinalStroke                    0.022764              -0.081412
# Vissage_M8_torque                     -0.445953              -0.057760
# Capuchon_insertion                    -0.043183              -0.249981
# Rodage_U                               0.013814               0.057027
# V1_torque                              0.116466               0.350925
# StartLinePeakForce                     0.043943               0.620728
# Vissage_M8_angle                       1.000000               0.073582
# SnapRingMidPointForce                  0.073582               1.000000
# V2_torque                              0.116468               0.355215
# Vissage_M8_angle_log                   0.964817               0.074045
# SnapRingFinalStroke_exp                0.026249              -0.222845
# Binar OP130_Resultat_Global_v          0.005470               0.014273
#
#                                V2_torque  Vissage_M8_angle_log  \
# Premier angle                   0.083662              0.021449
# SnapRingPeakForce               0.489280              0.107327
# Deuxième angle                  0.044249              0.023336
# Rodage_I                        0.038527              0.027576
# SnapRingFinalStroke            -0.425514              0.031721
# Vissage_M8_torque              -0.074945             -0.515324
# Capuchon_insertion             -0.689374             -0.043100
# Rodage_U                        0.175152              0.014373
# V1_torque                       0.953855              0.108191
# StartLinePeakForce              0.579126              0.037062
# Vissage_M8_angle                0.116468              0.964817
# SnapRingMidPointForce           0.355215              0.074045
# V2_torque                       1.000000              0.108450
# Vissage_M8_angle_log            0.108450              1.000000
# SnapRingFinalStroke_exp        -0.582425              0.038563
# Binar OP130_Resultat_Global_v  -0.040628              0.005051
#
#                                SnapRingFinalStroke_exp  \
# Premier angle                                -0.112748
# SnapRingPeakForce                            -0.012354
# Deuxième angle                               -0.073238
# Rodage_I                                      0.076714
# SnapRingFinalStroke                           0.795896
# Vissage_M8_torque                            -0.128840
# Capuchon_insertion                            0.188305
# Rodage_U                                     -0.038234
# V1_torque                                    -0.568716
# StartLinePeakForce                           -0.592980
# Vissage_M8_angle                              0.026249
# SnapRingMidPointForce                        -0.222845
# V2_torque                                    -0.582425
# Vissage_M8_angle_log                          0.038563
# SnapRingFinalStroke_exp                       1.000000
# Binar OP130_Resultat_Global_v                 0.018595
#
#                                Binar OP130_Resultat_Global_v
# Premier angle                                      -0.012793
# SnapRingPeakForce                                  -0.007290
# Deuxième angle                                     -0.006342
# Rodage_I                                            0.003763
# SnapRingFinalStroke                                 0.015148
# Vissage_M8_torque                                  -0.002984
# Capuchon_insertion                                  0.033914
# Rodage_U                                           -0.010492
# V1_torque                                          -0.039466
# StartLinePeakForce                                  0.010720
# Vissage_M8_angle                                    0.005470
# SnapRingMidPointForce                               0.014273
# V2_torque                                          -0.040628
# Vissage_M8_angle_log                                0.005051
# SnapRingFinalStroke_exp                             0.018595
# Binar OP130_Resultat_Global_v                       1.000000

# %%
visualization.plot_corr(df_training_inputs, width=10, height=10, 
                        print_value=False)

# %%
features_corr = \
        feature_engineering.get_features_correlated_to_target(
                df_training_inputs, target_feature='Binar OP130_Resultat_Global_v')

features_corr[:12]
# Out:
# Binar OP130_Resultat_Global_v    1.00
# V1_torque                       -0.04
# V2_torque                       -0.04
# Capuchon_insertion               0.03
# SnapRingFinalStroke              0.02
# SnapRingFinalStroke_exp          0.02
# Premier angle                   -0.01
# SnapRingPeakForce               -0.01
# Deuxième angle                  -0.01
# Rodage_U                        -0.01
# StartLinePeakForce               0.01
# Vissage_M8_angle                 0.01
# Name: Binar OP130_Resultat_Global_v, dtype: float64

# %%
cols_binaire = ['Binar OP130_Resultat_Global_v', 'Capuchon_insertion', 'V1_torque', 'V2_torque']

# %%
ax = df_training_inputs[ list(set(cols_to_plot2) - set(cols_binaire))].boxplot()
ax.tick_params(axis='x', labelrotation=90)

# %% [markdown]
# # Df_fail

# %%
df_fail = df_training_inputs[df_training_inputs['Binar OP130_Resultat_Global_v'] == 1]
df_fail.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305 entries, 40 to 34498
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Premier angle                  305 non-null    float64
#  1   SnapRingPeakForce              305 non-null    float64
#  2   Deuxième angle                 305 non-null    float64
#  3   Rodage_I                       305 non-null    float64
#  4   SnapRingFinalStroke            305 non-null    float64
#  5   Vissage_M8_torque              305 non-null    float64
#  6   Capuchon_insertion             305 non-null    float64
#  7   Rodage_U                       305 non-null    float64
#  8   V1_torque                      305 non-null    int64
#  9   StartLinePeakForce             305 non-null    float64
#  10  Vissage_M8_angle               305 non-null    float64
#  11  SnapRingMidPointForce          305 non-null    float64
#  12  V2_torque                      305 non-null    int64
#  13  Vissage_M8_angle_log           305 non-null    float64
#  14  SnapRingFinalStroke_exp        305 non-null    float64
#  15  Binar OP130_Resultat_Global_v  305 non-null    int64
# dtypes: float64(13), int64(3)
# memory usage: 40.5 KB

# %%
sm = scatter_matrix(df_fail[cols_to_plot2] ,figsize = (15, 10), alpha = 0.5, color = 'red')

visualization.rotate_labels(sm)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/misc.py:101: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/misc.py:102: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/misc.py:92: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %% [markdown]
# # Test/train division

# %%
df = df_training_inputs[cols_to_plot2]
df
# Out:
#        Rodage_U  V1_torque  Rodage_I  V2_torque  SnapRingMidPointForce  \
# 0         11.97          1    113.64          1                 109.62
# 1         11.97          0    109.77          0                 105.48
# 2         11.97          1    109.79          1                 100.03
# 3         11.97          1    113.25          1                 104.94
# 4         11.97          1    112.88          1                  99.19
# ...         ...        ...       ...        ...                    ...
# 34510     11.98          1    110.65          1                  98.76
# 34511     11.97          0    108.14          0                  98.37
# 34512     11.97          1    112.77          1                  92.92
# 34513     11.97          1    111.19          1                 101.21
# 34514     11.97          0    113.81          1                 102.72
#
#        Premier angle  SnapRingPeakForce  Deuxième angle  Vissage_M8_torque  \
# 0              180.4             190.51           173.1              12.16
# 1              138.7             147.70           163.5              12.19
# 2              180.9             150.87           181.2              12.24
# 3              173.5             159.56           151.8              12.35
# 4              174.5             172.29           177.5              12.19
# ...              ...                ...             ...                ...
# 34510          158.2             168.40           180.6              12.23
# 34511          139.4             146.24           154.5              12.27
# 34512          165.5             157.34           149.8              12.17
# 34513          152.4             165.07           140.0              12.34
# 34514          197.8             150.37           190.3              12.23
#
#        Capuchon_insertion  StartLinePeakForce  Vissage_M8_angle_log  \
# 0                     0.0               26.37              2.933857
# 1                     1.0               21.03              2.917771
# 2                     0.0               25.81              2.862201
# 3                     1.0               24.62              2.747271
# 4                     0.0               29.22              3.514526
# ...                   ...                 ...                   ...
# 34510                 0.0               24.03              2.694627
# 34511                 1.0               21.52              2.740840
# 34512                 0.0               22.65              3.194583
# 34513                 0.0               20.77              2.610070
# 34514                 0.0               26.43              3.068053
#
#        SnapRingFinalStroke_exp  Binar OP130_Resultat_Global_v
# 0                460468.625050                              0
# 1                498819.706587                              0
# 2                384615.725794                              0
# 3                369534.727474                              0
# 4                474491.982426                              0
# ...                        ...                            ...
# 34510            392385.478850                              0
# 34511            460468.625050                              0
# 34512            484077.356303                              0
# 34513            469770.708316                              0
# 34514            376999.824156                              0
#
# [34515 rows x 14 columns]

# %%
df.csv = df.to_csv(path_or_buf="./df_yudi.csv")

# %%
import pickle # to serialize/deserialize objects
from sklearn.model_selection import train_test_split
from statistics import mean

# %%
# !wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/andrea_models.py
# !wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py

from andrea_models import AndreaLinearRegression # In the course library
# Out:
# --2023-05-26 09:42:22--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/andrea_models.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3190 (3.1K) [text/plain]
# Saving to: ‘andrea_models.py’
#
# andrea_models.py    100%[===================>]   3.12K  --.-KB/s    in 0s
#
# 2023-05-26 09:42:23 (35.3 MB/s) - ‘andrea_models.py’ saved [3190/3190]
#
# --2023-05-26 09:42:23--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2206 (2.2K) [text/plain]
# Saving to: ‘feature_engineering.py.1’
#
# feature_engineering 100%[===================>]   2.15K  --.-KB/s    in 0s
#
# 2023-05-26 09:42:23 (25.0 MB/s) - ‘feature_engineering.py.1’ saved [2206/2206]

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=19)
df_test.head()

print('Training samples ', df_train.shape[0], '; Test samples ', df_test.shape[0])
# Out:
# Training samples  24160 ; Test samples  10355

# %% [markdown]
# # Regression logistique

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
        
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV, KFold

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler

from imblearn.over_sampling import SMOTE

# We import a function I prepared for you in the course library
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
from visualization import plot_conf_mat
# Out:
# --2023-05-26 09:47:20--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13023 (13K) [text/plain]
# Saving to: ‘visualization.py.1’
#
# visualization.py.1  100%[===================>]  12.72K  --.-KB/s    in 0s
#
# 2023-05-26 09:47:20 (45.5 MB/s) - ‘visualization.py.1’ saved [13023/13023]

# %% [markdown]
# Il faut selectionner les colonnes qui on veut analiser

# %%
columns = cols_to_plot

# %%
X_train = df_train[columns]
X_test = df_test[columns]

y_train = df_train['Binar OP130_Resultat_Global_v']
y_test = df_test['Binar OP130_Resultat_Global_v']

# %%
model = LogisticRegression(C=1e-9)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1e-09)

# %%
y_pred_proba = model.predict_proba(X_test)
y_pred_proba
# Out:
# array([[0.9952257 , 0.0047743 ],
#        [0.9826332 , 0.0173668 ],
#        [0.98906656, 0.01093344],
#        ...,
#        [0.98397108, 0.01602892],
#        [0.98331197, 0.01668803],
#        [0.99412028, 0.00587972]])

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pd.DataFrame({'true':y_test, 'pred':y_pred })

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9923708353452438

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)

# %%
model = LogisticRegression(C=1)
model.fit(X_train_scaled, y_train)
X_test_scaled = scaler.transform(X_test)
y_pred = model.predict(X_test_scaled)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.9923708353452438

# %%
class_names=np.array(["good", "bad"] )

# %%
plot_conf_mat(y_test, y_pred, class_names, normalize=False, 
              title="Confusion matrix", cmap=plt.cm.viridis)

# %% [markdown]
# Comme notre dataset est très desequilibré on doit faire une balance entre les classes

# %%
y_train.value_counts()
# Out:
# 0    23934
# 1      226
# Name: Binar OP130_Resultat_Global_v, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    10276
# 1       79
# Name: Binar OP130_Resultat_Global_v, dtype: int64

# %%
smote = SMOTE()

X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)
pd.value_counts(y_train_balanced)
# Out:
# 0    23934
# 1    23934
# Name: Binar OP130_Resultat_Global_v, dtype: int64

# %%
model.fit(X_train_balanced, y_train_balanced)
y_pred = model.predict(X_test)
plot_conf_mat(y_test, y_pred,class_names)
# Out:
# Normalized confusion matrix
# [[0.51313741 0.48686259]
#  [0.36708861 0.63291139]]
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.51405118300338

# %% [markdown]
# C'est mieux que avant

# %%
print( classification_report(y_test, y_pred) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.51      0.68     10276
#            1       0.01      0.63      0.02        79
#
#     accuracy                           0.51     10355
#    macro avg       0.50      0.57      0.35     10355
# weighted avg       0.99      0.51      0.67     10355

# %% [markdown]
# # Grid Search pour trouver le mieulleure regularization

# %% [markdown]
# Essaie avec Multinomial Regression

# %%
def MyMultinomialRegression(C=1e-9):
    return make_pipeline(
        StandardScaler(),
        LogisticRegression(multi_class="multinomial", solver="lbfgs", C=C)
    )

# %%
model_m = MyMultinomialRegression(C=1)
model_m.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=1, multi_class='multinomial'))])

# %%
y_pred_m = model_m.predict(X_test)
y_pred_m
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_pred_m, y_test)
# Out:
# 0.9923708353452438

# %%
smote = SMOTE()

X_train_balanced_m, y_train_balanced_m = smote.fit_resample(X_train, y_train)
pd.value_counts(y_train_balanced_m)
# Out:
# 0    23934
# 1    23934
# Name: Binar OP130_Resultat_Global_v, dtype: int64

# %%
model.fit(X_train_balanced_m, y_train_balanced_m)
y_pred = model.predict(X_test)
plot_conf_mat(y_test, y_pred,class_names)
# Out:
# Normalized confusion matrix
# [[0.51323472 0.48676528]
#  [0.36708861 0.63291139]]
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.5141477547078706

# %%
print( classification_report(y_test, y_pred) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.51      0.68     10276
#            1       0.01      0.63      0.02        79
#
#     accuracy                           0.51     10355
#    macro avg       0.50      0.57      0.35     10355
# weighted avg       0.99      0.51      0.67     10355

# %%
GridSearchCV(MyMultinomialRegression(), [] ).get_params().keys()
# Out:
# dict_keys(['cv', 'error_score', 'estimator__memory', 'estimator__steps', 'estimator__verbose', 'estimator__standardscaler', 'estimator__logisticregression', 'estimator__standardscaler__copy', 'estimator__standardscaler__with_mean', 'estimator__standardscaler__with_std', 'estimator__logisticregression__C', 'estimator__logisticregression__class_weight', 'estimator__logisticregression__dual', 'estimator__logisticregression__fit_intercept', 'estimator__logisticregression__intercept_scaling', 'estimator__logisticregression__l1_ratio', 'estimator__logisticregression__max_iter', 'estimator__logisticregression__multi_class', 'estimator__logisticregression__n_jobs', 'estimator__logisticregression__penalty', 'estimator__logisticregression__random_state', 'estimator__logisticregression__solver', 'estimator__logisticregression__tol', 'estimator__logisticregression__verbose', 'estimator__logisticregression__warm_start', 'estimator', 'n_jobs', 'param_grid', 'pre_dispatch', 'refit', 'return_train_score', 'scoring', 'verbose'])

# %%
k_fold = KFold(n_splits=5, shuffle=True, random_state=5)

parameters_to_test = [{ 'logisticregression__C': [1e-9, 1e-3, 0.01, 0.1, 1, 10, 100, 1000, 10000] }]

# The different scoring metrics available are in:
#     https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
grid = GridSearchCV(MyMultinomialRegression(), parameters_to_test, cv=k_fold, 
                    scoring='f1_macro')

# %%
grid.fit(X_train_balanced, y_train_balanced_m)
print("The best regularization weigth is ", grid.best_params_)
# Out:
# The best regularization weigth is  {'logisticregression__C': 0.1}

# %%
model = grid.best_estimator_
model.fit(X_train_balanced, y_train_balanced_m)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_conf_mat(y_test, y_pred, class_names)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.81     10276
#            1       0.01      0.52      0.02        79
#
#     accuracy                           0.68     10355
#    macro avg       0.50      0.60      0.41     10355
# weighted avg       0.99      0.68      0.80     10355
#
# Normalized confusion matrix
# [[0.67720903 0.32279097]
#  [0.48101266 0.51898734]]
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>
