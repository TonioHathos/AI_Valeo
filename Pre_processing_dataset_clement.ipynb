# %% [markdown]
# <a href="https://colab.research.google.com/github/TonioHathos/AI_Valeo/blob/main/Pre_processing_dataset_clement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initialisation : biblothèques et récupération dataframes

# %%
import pandas as pd # For dataframes (tables)
import numpy as np # For numerical operations
import math 
import matplotlib.pyplot as plt # For plots
import os # To import external python files
import sys# To import external python files
import missingno as msno

from pandas.plotting import scatter_matrix

# %%
! rm -f *.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/testinputs.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/traininginputs.csv
! wget https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/trainingoutput.csv
# Out:
# --2023-05-15 15:31:08--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/testinputs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795776 (777K) [text/plain]
# Saving to: ‘testinputs.csv’
#
# testinputs.csv      100%[===================>] 777.12K  --.-KB/s    in 0.03s
#
# 2023-05-15 15:31:08 (21.8 MB/s) - ‘testinputs.csv’ saved [795776/795776]
#
# --2023-05-15 15:31:09--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/traininginputs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3432084 (3.3M) [text/plain]
# Saving to: ‘traininginputs.csv’
#
# traininginputs.csv  100%[===================>]   3.27M  --.-KB/s    in 0.05s
#
# 2023-05-15 15:31:09 (60.5 MB/s) - ‘traininginputs.csv’ saved [3432084/3432084]
#
# --2023-05-15 15:31:09--  https://raw.githubusercontent.com/TonioHathos/AI_Valeo/master/trainingoutput.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1000980 (978K) [text/plain]
# Saving to: ‘trainingoutput.csv’
#
# trainingoutput.csv  100%[===================>] 977.52K  --.-KB/s    in 0.03s
#
# 2023-05-15 15:31:09 (28.6 MB/s) - ‘trainingoutput.csv’ saved [1000980/1000980]

# %%
df_test_inputs = pd.read_csv('testinputs.csv')
df_training_inputs = pd.read_csv('traininginputs.csv')
df_training_output = pd.read_csv('trainingoutput.csv')

# %% [markdown]
# # Visu rapide sur testinputs.csv

# %%
df_test_inputs.shape
# Out:
# (8001, 14)

# %%
df_test_inputs.describe()
# Out:
#        OP070_V_1_angle_value  OP090_SnapRingPeakForce_value  \
# count            8001.000000                    8001.000000
# mean              159.849919                     156.836130
# std                15.624188                      11.683895
# min               101.900000                       0.000000
# 25%               148.500000                     148.970000
# 50%               158.000000                     156.220000
# 75%               169.100000                     164.490000
# max               198.200000                     191.340000
#
#        OP070_V_2_angle_value  OP120_Rodage_I_mesure_value  \
# count            8001.000000                  8001.000000
# mean              159.678965                   113.379749
# std                15.238943                     3.547692
# min               103.500000                   102.420000
# 25%               149.500000                   111.090000
# 50%               158.700000                   113.200000
# 75%               168.900000                   115.370000
# max               198.000000                   186.310000
#
#        OP090_SnapRingFinalStroke_value  OP110_Vissage_M8_torque_value  \
# count                      8001.000000                    8001.000000
# mean                         11.968191                      12.254094
# std                           0.266558                       0.145903
# min                           0.000000                       0.570000
# 25%                          11.850000                      12.210000
# 50%                          12.040000                      12.250000
# 75%                          12.080000                      12.300000
# max                          12.150000                      12.500000
#
#        OP100_Capuchon_insertion_mesure  OP120_Rodage_U_mesure_value  \
# count                      3641.000000                  8001.000000
# mean                          0.388753                    11.971056
# std                           0.024336                     0.003082
# min                           0.250000                    11.970000
# 25%                           0.380000                    11.970000
# 50%                           0.390000                    11.970000
# 75%                           0.410000                    11.970000
# max                           0.420000                    11.990000
#
#        OP070_V_1_torque_value  OP090_StartLinePeakForce_value  \
# count             8001.000000                      8001.00000
# mean                 6.548061                        23.58853
# std                  0.097780                         2.57426
# min                  5.810000                         0.00000
# 25%                  6.410000                        22.23000
# 50%                  6.610000                        23.82000
# 75%                  6.620000                        25.24000
# max                  6.660000                        36.43000
#
#        OP110_Vissage_M8_angle_value  OP090_SnapRingMidPointForce_val  \
# count                   8001.000000                      8001.000000
# mean                      17.929671                        97.607625
# std                        6.709905                         7.023431
# min                        0.000000                         0.000000
# 25%                       13.600000                        94.290000
# 50%                       16.500000                        98.410000
# 75%                       20.200000                       102.230000
# max                       72.600000                       133.550000
#
#        OP070_V_2_torque_value
# count             8001.000000
# mean                 6.549979
# std                  0.095063
# min                  5.900000
# 25%                  6.420000
# 50%                  6.610000
# 75%                  6.610000
# max                  6.680000

# %%
with pd.option_context('display.max_columns', df_test_inputs.shape[1]):
    print(df_test_inputs.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  OP070_V_1_angle_value  \
# count                         8001            8001.000000
# unique                        8001                    NaN
# top     I-B-XA1207672-190520-00632                    NaN
# freq                             1                    NaN
# mean                           NaN             159.849919
# std                            NaN              15.624188
# min                            NaN             101.900000
# 25%                            NaN             148.500000
# 50%                            NaN             158.000000
# 75%                            NaN             169.100000
# max                            NaN             198.200000
#
#         OP090_SnapRingPeakForce_value  OP070_V_2_angle_value  \
# count                     8001.000000            8001.000000
# unique                            NaN                    NaN
# top                               NaN                    NaN
# freq                              NaN                    NaN
# mean                       156.836130             159.678965
# std                         11.683895              15.238943
# min                          0.000000             103.500000
# 25%                        148.970000             149.500000
# 50%                        156.220000             158.700000
# 75%                        164.490000             168.900000
# max                        191.340000             198.000000
#
#         OP120_Rodage_I_mesure_value  OP090_SnapRingFinalStroke_value  \
# count                   8001.000000                      8001.000000
# unique                          NaN                              NaN
# top                             NaN                              NaN
# freq                            NaN                              NaN
# mean                     113.379749                        11.968191
# std                        3.547692                         0.266558
# min                      102.420000                         0.000000
# 25%                      111.090000                        11.850000
# 50%                      113.200000                        12.040000
# 75%                      115.370000                        12.080000
# max                      186.310000                        12.150000
#
#         OP110_Vissage_M8_torque_value  OP100_Capuchon_insertion_mesure  \
# count                     8001.000000                      3641.000000
# unique                            NaN                              NaN
# top                               NaN                              NaN
# freq                              NaN                              NaN
# mean                        12.254094                         0.388753
# std                          0.145903                         0.024336
# min                          0.570000                         0.250000
# 25%                         12.210000                         0.380000
# 50%                         12.250000                         0.390000
# 75%                         12.300000                         0.410000
# max                         12.500000                         0.420000
#
#         OP120_Rodage_U_mesure_value  OP070_V_1_torque_value  \
# count                   8001.000000             8001.000000
# unique                          NaN                     NaN
# top                             NaN                     NaN
# freq                            NaN                     NaN
# mean                      11.971056                6.548061
# std                        0.003082                0.097780
# min                       11.970000                5.810000
# 25%                       11.970000                6.410000
# 50%                       11.970000                6.610000
# 75%                       11.970000                6.620000
# max                       11.990000                6.660000
#
#         OP090_StartLinePeakForce_value  OP110_Vissage_M8_angle_value  \
# count                       8001.00000                   8001.000000
# unique                             NaN                           NaN
# top                                NaN                           NaN
# freq                               NaN                           NaN
# mean                          23.58853                     17.929671
# std                            2.57426                      6.709905
# min                            0.00000                      0.000000
# 25%                           22.23000                     13.600000
# 50%                           23.82000                     16.500000
# 75%                           25.24000                     20.200000
# max                           36.43000                     72.600000
#
#         OP090_SnapRingMidPointForce_val  OP070_V_2_torque_value
# count                       8001.000000             8001.000000
# unique                              NaN                     NaN
# top                                 NaN                     NaN
# freq                                NaN                     NaN
# mean                          97.607625                6.549979
# std                            7.023431                0.095063
# min                            0.000000                5.900000
# 25%                           94.290000                6.420000
# 50%                           98.410000                6.610000
# 75%                          102.230000                6.610000
# max                          133.550000                6.680000

# %% [markdown]
# # Visu rapide sur traininginputs.csv

# %%
df_training_inputs.shape
# Out:
# (34515, 14)

# %%
df_training_inputs.describe()
# Out:
#        OP070_V_1_angle_value  OP090_SnapRingPeakForce_value  \
# count           34515.000000                   34515.000000
# mean              159.906922                     156.915055
# std                15.662650                      11.271492
# min               101.800000                       0.000000
# 25%               148.700000                     149.210000
# 50%               158.000000                     156.180000
# 75%               169.300000                     164.380000
# max               198.300000                     196.920000
#
#        OP070_V_2_angle_value  OP120_Rodage_I_mesure_value  \
# count           34515.000000                 34515.000000
# mean              159.618236                   113.350222
# std                15.091490                     3.528522
# min                82.000000                    99.990000
# 25%               149.400000                   111.040000
# 50%               158.700000                   113.160000
# 75%               168.900000                   115.380000
# max               198.100000                   177.950000
#
#        OP090_SnapRingFinalStroke_value  OP110_Vissage_M8_torque_value  \
# count                     34515.000000                   34515.000000
# mean                         11.970190                      12.256785
# std                           0.169873                       0.065319
# min                           0.000000                      12.030000
# 25%                          11.850000                      12.210000
# 50%                          12.040000                      12.260000
# 75%                          12.080000                      12.300000
# max                          12.190000                      12.500000
#
#        OP100_Capuchon_insertion_mesure  OP120_Rodage_U_mesure_value  \
# count                     15888.000000                 34515.000000
# mean                          0.388173                    11.971027
# std                           0.024425                     0.003050
# min                           0.240000                    11.970000
# 25%                           0.380000                    11.970000
# 50%                           0.390000                    11.970000
# 75%                           0.410000                    11.970000
# max                           0.420000                    11.990000
#
#        OP070_V_1_torque_value  OP090_StartLinePeakForce_value  \
# count            34515.000000                    34515.000000
# mean                 6.548403                       23.630152
# std                  0.097602                        2.546341
# min                  5.670000                        0.000000
# 25%                  6.410000                       22.280000
# 50%                  6.610000                       23.880000
# 75%                  6.620000                       25.290000
# max                  6.670000                       43.410000
#
#        OP110_Vissage_M8_angle_value  OP090_SnapRingMidPointForce_val  \
# count                  34515.000000                     34515.000000
# mean                      17.878398                        97.700978
# std                        6.785079                         6.837714
# min                        6.300000                         0.000000
# 25%                       13.500000                        94.310000
# 50%                       16.400000                        98.500000
# 75%                       20.200000                       102.230000
# max                       84.600000                       127.300000
#
#        OP070_V_2_torque_value
# count            34515.000000
# mean                 6.550867
# std                  0.094814
# min                  5.740000
# 25%                  6.420000
# 50%                  6.610000
# 75%                  6.610000
# max                  6.670000

# %%
with pd.option_context('display.max_columns', df_training_inputs.shape[1]):
    print(df_training_inputs.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  OP070_V_1_angle_value  \
# count                        34515           34515.000000
# unique                       34515                    NaN
# top     I-B-XA1207672-190429-00688                    NaN
# freq                             1                    NaN
# mean                           NaN             159.906922
# std                            NaN              15.662650
# min                            NaN             101.800000
# 25%                            NaN             148.700000
# 50%                            NaN             158.000000
# 75%                            NaN             169.300000
# max                            NaN             198.300000
#
#         OP090_SnapRingPeakForce_value  OP070_V_2_angle_value  \
# count                    34515.000000           34515.000000
# unique                            NaN                    NaN
# top                               NaN                    NaN
# freq                              NaN                    NaN
# mean                       156.915055             159.618236
# std                         11.271492              15.091490
# min                          0.000000              82.000000
# 25%                        149.210000             149.400000
# 50%                        156.180000             158.700000
# 75%                        164.380000             168.900000
# max                        196.920000             198.100000
#
#         OP120_Rodage_I_mesure_value  OP090_SnapRingFinalStroke_value  \
# count                  34515.000000                     34515.000000
# unique                          NaN                              NaN
# top                             NaN                              NaN
# freq                            NaN                              NaN
# mean                     113.350222                        11.970190
# std                        3.528522                         0.169873
# min                       99.990000                         0.000000
# 25%                      111.040000                        11.850000
# 50%                      113.160000                        12.040000
# 75%                      115.380000                        12.080000
# max                      177.950000                        12.190000
#
#         OP110_Vissage_M8_torque_value  OP100_Capuchon_insertion_mesure  \
# count                    34515.000000                     15888.000000
# unique                            NaN                              NaN
# top                               NaN                              NaN
# freq                              NaN                              NaN
# mean                        12.256785                         0.388173
# std                          0.065319                         0.024425
# min                         12.030000                         0.240000
# 25%                         12.210000                         0.380000
# 50%                         12.260000                         0.390000
# 75%                         12.300000                         0.410000
# max                         12.500000                         0.420000
#
#         OP120_Rodage_U_mesure_value  OP070_V_1_torque_value  \
# count                  34515.000000            34515.000000
# unique                          NaN                     NaN
# top                             NaN                     NaN
# freq                            NaN                     NaN
# mean                      11.971027                6.548403
# std                        0.003050                0.097602
# min                       11.970000                5.670000
# 25%                       11.970000                6.410000
# 50%                       11.970000                6.610000
# 75%                       11.970000                6.620000
# max                       11.990000                6.670000
#
#         OP090_StartLinePeakForce_value  OP110_Vissage_M8_angle_value  \
# count                     34515.000000                  34515.000000
# unique                             NaN                           NaN
# top                                NaN                           NaN
# freq                               NaN                           NaN
# mean                         23.630152                     17.878398
# std                           2.546341                      6.785079
# min                           0.000000                      6.300000
# 25%                          22.280000                     13.500000
# 50%                          23.880000                     16.400000
# 75%                          25.290000                     20.200000
# max                          43.410000                     84.600000
#
#         OP090_SnapRingMidPointForce_val  OP070_V_2_torque_value
# count                      34515.000000            34515.000000
# unique                              NaN                     NaN
# top                                 NaN                     NaN
# freq                                NaN                     NaN
# mean                          97.700978                6.550867
# std                            6.837714                0.094814
# min                            0.000000                5.740000
# 25%                           94.310000                6.420000
# 50%                           98.500000                6.610000
# 75%                          102.230000                6.610000
# max                          127.300000                6.670000

# %% [markdown]
# # Visu rapide sur trainingoutput.csv

# %%
df_training_output.shape
# Out:
# (34515, 2)

# %%
df_training_output.describe()
# Out:
#        Binar OP130_Resultat_Global_v
# count                   34515.000000
# mean                        0.008837
# std                         0.093589
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         1.000000

# %%
with pd.option_context('display.max_columns', df_training_output.shape[1]):
    print(df_training_output.describe(include='all'))
# Out:
#                     PROC_TRACEINFO  Binar OP130_Resultat_Global_v
# count                        34515                   34515.000000
# unique                       34515                            NaN
# top     I-B-XA1207672-190429-00688                            NaN
# freq                             1                            NaN
# mean                           NaN                       0.008837
# std                            NaN                       0.093589
# min                            NaN                       0.000000
# 25%                            NaN                       0.000000
# 50%                            NaN                       0.000000
# 75%                            NaN                       0.000000
# max                            NaN                       1.000000

# %% [markdown]
# 1st and 2nd order statistics

# %%
df_test_inputs.hist()
# Out:
# array([[<Axes: title={'center': 'OP070_V_1_angle_value'}>,
#         <Axes: title={'center': 'OP090_SnapRingPeakForce_value'}>,
#         <Axes: title={'center': 'OP070_V_2_angle_value'}>,
#         <Axes: title={'center': 'OP120_Rodage_I_mesure_value'}>],
#        [<Axes: title={'center': 'OP090_SnapRingFinalStroke_value'}>,
#         <Axes: title={'center': 'OP110_Vissage_M8_torque_value'}>,
#         <Axes: title={'center': 'OP100_Capuchon_insertion_mesure'}>,
#         <Axes: title={'center': 'OP120_Rodage_U_mesure_value'}>],
#        [<Axes: title={'center': 'OP070_V_1_torque_value'}>,
#         <Axes: title={'center': 'OP090_StartLinePeakForce_value'}>,
#         <Axes: title={'center': 'OP110_Vissage_M8_angle_value'}>,
#         <Axes: title={'center': 'OP090_SnapRingMidPointForce_val'}>],
#        [<Axes: title={'center': 'OP070_V_2_torque_value'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
df_training_inputs.hist()
# Out:
# array([[<Axes: title={'center': 'OP070_V_1_angle_value'}>,
#         <Axes: title={'center': 'OP090_SnapRingPeakForce_value'}>,
#         <Axes: title={'center': 'OP070_V_2_angle_value'}>,
#         <Axes: title={'center': 'OP120_Rodage_I_mesure_value'}>],
#        [<Axes: title={'center': 'OP090_SnapRingFinalStroke_value'}>,
#         <Axes: title={'center': 'OP110_Vissage_M8_torque_value'}>,
#         <Axes: title={'center': 'OP100_Capuchon_insertion_mesure'}>,
#         <Axes: title={'center': 'OP120_Rodage_U_mesure_value'}>],
#        [<Axes: title={'center': 'OP070_V_1_torque_value'}>,
#         <Axes: title={'center': 'OP090_StartLinePeakForce_value'}>,
#         <Axes: title={'center': 'OP110_Vissage_M8_angle_value'}>,
#         <Axes: title={'center': 'OP090_SnapRingMidPointForce_val'}>],
#        [<Axes: title={'center': 'OP070_V_2_torque_value'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
df_training_output.hist()
# Out:
# array([[<Axes: title={'center': 'Binar OP130_Resultat_Global_v'}>]],
#       dtype=object)

# %% [markdown]
# # On détermine les colonnes qui ont des données manquantes

# %%
df_test_inputs.columns[df_test_inputs.isnull().any()].tolist()
# Out:
# ['OP100_Capuchon_insertion_mesure']

# %%
df_training_inputs.columns[df_training_inputs.isnull().any()].tolist()
# Out:
# ['OP100_Capuchon_insertion_mesure']

# %%
df_training_output.columns[df_training_output.isnull().any()].tolist()
# Out:
# []

# %%
df_training_inputs.shape
# Out:
# (34515, 14)

# %%
print("NaN of OP100_Capuchon_insertion_mesure in training = ", df_training_inputs['OP100_Capuchon_insertion_mesure'].isna().sum() )
print("NaN of OP100_Capuchon_insertion_mesure in test = ", df_test_inputs['OP100_Capuchon_insertion_mesure'].isna().sum() )
# Out:
# NaN of OP100_Capuchon_insertion_mesure in training =  18627
# NaN of OP100_Capuchon_insertion_mesure in test =  4360

# %% [markdown]
# # On relie le dataset des données d'entrainement avec le label en sortie

# %%
df_training = pd.merge(df_training_inputs, df_training_output, on='PROC_TRACEINFO')

# %%
df_training = df_training.drop(columns=["PROC_TRACEINFO"])

# %%
msno.matrix(df_training)
# Out:
# <Axes: >

# %% [markdown]
# ## Stratégie 1 : Supprimer l'unique colonne avec des valeurs manquantes

# %%
df_training_cleaned = df_training.drop(columns=["OP100_Capuchon_insertion_mesure"])
df_test_inputs_cleaned = df_test_inputs.drop(columns=["OP100_Capuchon_insertion_mesure", "PROC_TRACEINFO"])

# %% [markdown]
# ## Stratégie 2 : Supprimer les lignes avec des valeurs manquantes

# %%
df_training_nonull = df_training.dropna()

# %% [markdown]
# # Categorical features

# %%
df_training_cleaned.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34515 entries, 0 to 34514
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OP070_V_1_angle_value            34515 non-null  float64
#  1   OP090_SnapRingPeakForce_value    34515 non-null  float64
#  2   OP070_V_2_angle_value            34515 non-null  float64
#  3   OP120_Rodage_I_mesure_value      34515 non-null  float64
#  4   OP090_SnapRingFinalStroke_value  34515 non-null  float64
#  5   OP110_Vissage_M8_torque_value    34515 non-null  float64
#  6   OP120_Rodage_U_mesure_value      34515 non-null  float64
#  7   OP070_V_1_torque_value           34515 non-null  float64
#  8   OP090_StartLinePeakForce_value   34515 non-null  float64
#  9   OP110_Vissage_M8_angle_value     34515 non-null  float64
#  10  OP090_SnapRingMidPointForce_val  34515 non-null  float64
#  11  OP070_V_2_torque_value           34515 non-null  float64
#  12  Binar OP130_Resultat_Global_v    34515 non-null  int64
# dtypes: float64(12), int64(1)
# memory usage: 3.7 MB

# %%
df_training_nonull.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15888 entries, 1 to 34511
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OP070_V_1_angle_value            15888 non-null  float64
#  1   OP090_SnapRingPeakForce_value    15888 non-null  float64
#  2   OP070_V_2_angle_value            15888 non-null  float64
#  3   OP120_Rodage_I_mesure_value      15888 non-null  float64
#  4   OP090_SnapRingFinalStroke_value  15888 non-null  float64
#  5   OP110_Vissage_M8_torque_value    15888 non-null  float64
#  6   OP100_Capuchon_insertion_mesure  15888 non-null  float64
#  7   OP120_Rodage_U_mesure_value      15888 non-null  float64
#  8   OP070_V_1_torque_value           15888 non-null  float64
#  9   OP090_StartLinePeakForce_value   15888 non-null  float64
#  10  OP110_Vissage_M8_angle_value     15888 non-null  float64
#  11  OP090_SnapRingMidPointForce_val  15888 non-null  float64
#  12  OP070_V_2_torque_value           15888 non-null  float64
#  13  Binar OP130_Resultat_Global_v    15888 non-null  int64
# dtypes: float64(13), int64(1)
# memory usage: 1.8 MB

# %%
df_training_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34515 entries, 0 to 34514
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PROC_TRACEINFO                 34515 non-null  object
#  1   Binar OP130_Resultat_Global_v  34515 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 539.4+ KB

# %%
df_training_cleaned.csv = df_training_cleaned.to_csv(path_or_buf="./df_training_cleaned.csv")

# %% [markdown]
# # Correlations

# %%
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
import visualization
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
import feature_engineering
# Out:
# --2023-05-15 15:56:07--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13023 (13K) [text/plain]
# Saving to: ‘visualization.py.2’
#
# visualization.py.2  100%[===================>]  12.72K  --.-KB/s    in 0s
#
# 2023-05-15 15:56:08 (70.2 MB/s) - ‘visualization.py.2’ saved [13023/13023]
#
# --2023-05-15 15:56:08--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2206 (2.2K) [text/plain]
# Saving to: ‘feature_engineering.py’
#
# feature_engineering 100%[===================>]   2.15K  --.-KB/s    in 0s
#
# 2023-05-15 15:56:08 (4.25 MB/s) - ‘feature_engineering.py’ saved [2206/2206]

# %% [markdown]
# ## scatter_matrix

# %% [markdown]
# ## Pearson's correlation

# %% [markdown]
# ### Cleaned

# %%
corrmatrix = df_training_cleaned.corr()
corrmatrix
# Out:
#                                  OP070_V_1_angle_value  \
# OP070_V_1_angle_value                         1.000000
# OP090_SnapRingPeakForce_value                 0.008887
# OP070_V_2_angle_value                         0.186781
# OP120_Rodage_I_mesure_value                   0.035003
# OP090_SnapRingFinalStroke_value              -0.087910
# OP110_Vissage_M8_torque_value                -0.017578
# OP120_Rodage_U_mesure_value                  -0.007284
# OP070_V_1_torque_value                       -0.012960
# OP090_StartLinePeakForce_value                0.057592
# OP110_Vissage_M8_angle_value                  0.014374
# OP090_SnapRingMidPointForce_val               0.066924
# OP070_V_2_torque_value                        0.073814
# Binar OP130_Resultat_Global_v                -0.012793
#
#                                  OP090_SnapRingPeakForce_value  \
# OP070_V_1_angle_value                                 0.008887
# OP090_SnapRingPeakForce_value                         1.000000
# OP070_V_2_angle_value                                 0.038399
# OP120_Rodage_I_mesure_value                           0.055235
# OP090_SnapRingFinalStroke_value                       0.076451
# OP110_Vissage_M8_torque_value                        -0.134780
# OP120_Rodage_U_mesure_value                           0.135288
# OP070_V_1_torque_value                                0.489633
# OP090_StartLinePeakForce_value                        0.336620
# OP110_Vissage_M8_angle_value                          0.106753
# OP090_SnapRingMidPointForce_val                       0.345139
# OP070_V_2_torque_value                                0.481550
# Binar OP130_Resultat_Global_v                        -0.007290
#
#                                  OP070_V_2_angle_value  \
# OP070_V_1_angle_value                         0.186781
# OP090_SnapRingPeakForce_value                 0.038399
# OP070_V_2_angle_value                         1.000000
# OP120_Rodage_I_mesure_value                   0.036301
# OP090_SnapRingFinalStroke_value              -0.060931
# OP110_Vissage_M8_torque_value                -0.030284
# OP120_Rodage_U_mesure_value                   0.003245
# OP070_V_1_torque_value                        0.059178
# OP090_StartLinePeakForce_value                0.047190
# OP110_Vissage_M8_angle_value                  0.017727
# OP090_SnapRingMidPointForce_val               0.050193
# OP070_V_2_torque_value                        0.017812
# Binar OP130_Resultat_Global_v                -0.006342
#
#                                  OP120_Rodage_I_mesure_value  \
# OP070_V_1_angle_value                               0.035003
# OP090_SnapRingPeakForce_value                       0.055235
# OP070_V_2_angle_value                               0.036301
# OP120_Rodage_I_mesure_value                         1.000000
# OP090_SnapRingFinalStroke_value                     0.060014
# OP110_Vissage_M8_torque_value                      -0.046313
# OP120_Rodage_U_mesure_value                        -0.118751
# OP070_V_1_torque_value                              0.034240
# OP090_StartLinePeakForce_value                      0.002962
# OP110_Vissage_M8_angle_value                        0.025043
# OP090_SnapRingMidPointForce_val                     0.046556
# OP070_V_2_torque_value                              0.034342
# Binar OP130_Resultat_Global_v                       0.003763
#
#                                  OP090_SnapRingFinalStroke_value  \
# OP070_V_1_angle_value                                  -0.087910
# OP090_SnapRingPeakForce_value                           0.076451
# OP070_V_2_angle_value                                  -0.060931
# OP120_Rodage_I_mesure_value                             0.060014
# OP090_SnapRingFinalStroke_value                         1.000000
# OP110_Vissage_M8_torque_value                          -0.095903
# OP120_Rodage_U_mesure_value                            -0.022536
# OP070_V_1_torque_value                                 -0.380948
# OP090_StartLinePeakForce_value                         -0.381450
# OP110_Vissage_M8_angle_value                            0.022764
# OP090_SnapRingMidPointForce_val                        -0.081412
# OP070_V_2_torque_value                                 -0.407915
# Binar OP130_Resultat_Global_v                           0.015148
#
#                                  OP110_Vissage_M8_torque_value  \
# OP070_V_1_angle_value                                -0.017578
# OP090_SnapRingPeakForce_value                        -0.134780
# OP070_V_2_angle_value                                -0.030284
# OP120_Rodage_I_mesure_value                          -0.046313
# OP090_SnapRingFinalStroke_value                      -0.095903
# OP110_Vissage_M8_torque_value                         1.000000
# OP120_Rodage_U_mesure_value                          -0.031115
# OP070_V_1_torque_value                               -0.076357
# OP090_StartLinePeakForce_value                        0.009997
# OP110_Vissage_M8_angle_value                         -0.445953
# OP090_SnapRingMidPointForce_val                      -0.057760
# OP070_V_2_torque_value                               -0.073071
# Binar OP130_Resultat_Global_v                        -0.002984
#
#                                  OP120_Rodage_U_mesure_value  \
# OP070_V_1_angle_value                              -0.007284
# OP090_SnapRingPeakForce_value                       0.135288
# OP070_V_2_angle_value                               0.003245
# OP120_Rodage_I_mesure_value                        -0.118751
# OP090_SnapRingFinalStroke_value                    -0.022536
# OP110_Vissage_M8_torque_value                      -0.031115
# OP120_Rodage_U_mesure_value                         1.000000
# OP070_V_1_torque_value                              0.169246
# OP090_StartLinePeakForce_value                      0.087487
# OP110_Vissage_M8_angle_value                        0.013814
# OP090_SnapRingMidPointForce_val                     0.057027
# OP070_V_2_torque_value                              0.172109
# Binar OP130_Resultat_Global_v                      -0.010492
#
#                                  OP070_V_1_torque_value  \
# OP070_V_1_angle_value                         -0.012960
# OP090_SnapRingPeakForce_value                  0.489633
# OP070_V_2_angle_value                          0.059178
# OP120_Rodage_I_mesure_value                    0.034240
# OP090_SnapRingFinalStroke_value               -0.380948
# OP110_Vissage_M8_torque_value                 -0.076357
# OP120_Rodage_U_mesure_value                    0.169246
# OP070_V_1_torque_value                         1.000000
# OP090_StartLinePeakForce_value                 0.543089
# OP110_Vissage_M8_angle_value                   0.112377
# OP090_SnapRingMidPointForce_val                0.334814
# OP070_V_2_torque_value                         0.896698
# Binar OP130_Resultat_Global_v                 -0.037438
#
#                                  OP090_StartLinePeakForce_value  \
# OP070_V_1_angle_value                                  0.057592
# OP090_SnapRingPeakForce_value                          0.336620
# OP070_V_2_angle_value                                  0.047190
# OP120_Rodage_I_mesure_value                            0.002962
# OP090_SnapRingFinalStroke_value                       -0.381450
# OP110_Vissage_M8_torque_value                          0.009997
# OP120_Rodage_U_mesure_value                            0.087487
# OP070_V_1_torque_value                                 0.543089
# OP090_StartLinePeakForce_value                         1.000000
# OP110_Vissage_M8_angle_value                           0.043943
# OP090_SnapRingMidPointForce_val                        0.620728
# OP070_V_2_torque_value                                 0.562435
# Binar OP130_Resultat_Global_v                          0.010720
#
#                                  OP110_Vissage_M8_angle_value  \
# OP070_V_1_angle_value                                0.014374
# OP090_SnapRingPeakForce_value                        0.106753
# OP070_V_2_angle_value                                0.017727
# OP120_Rodage_I_mesure_value                          0.025043
# OP090_SnapRingFinalStroke_value                      0.022764
# OP110_Vissage_M8_torque_value                       -0.445953
# OP120_Rodage_U_mesure_value                          0.013814
# OP070_V_1_torque_value                               0.112377
# OP090_StartLinePeakForce_value                       0.043943
# OP110_Vissage_M8_angle_value                         1.000000
# OP090_SnapRingMidPointForce_val                      0.073582
# OP070_V_2_torque_value                               0.113109
# Binar OP130_Resultat_Global_v                        0.005470
#
#                                  OP090_SnapRingMidPointForce_val  \
# OP070_V_1_angle_value                                   0.066924
# OP090_SnapRingPeakForce_value                           0.345139
# OP070_V_2_angle_value                                   0.050193
# OP120_Rodage_I_mesure_value                             0.046556
# OP090_SnapRingFinalStroke_value                        -0.081412
# OP110_Vissage_M8_torque_value                          -0.057760
# OP120_Rodage_U_mesure_value                             0.057027
# OP070_V_1_torque_value                                  0.334814
# OP090_StartLinePeakForce_value                          0.620728
# OP110_Vissage_M8_angle_value                            0.073582
# OP090_SnapRingMidPointForce_val                         1.000000
# OP070_V_2_torque_value                                  0.346948
# Binar OP130_Resultat_Global_v                           0.014273
#
#                                  OP070_V_2_torque_value  \
# OP070_V_1_angle_value                          0.073814
# OP090_SnapRingPeakForce_value                  0.481550
# OP070_V_2_angle_value                          0.017812
# OP120_Rodage_I_mesure_value                    0.034342
# OP090_SnapRingFinalStroke_value               -0.407915
# OP110_Vissage_M8_torque_value                 -0.073071
# OP120_Rodage_U_mesure_value                    0.172109
# OP070_V_1_torque_value                         0.896698
# OP090_StartLinePeakForce_value                 0.562435
# OP110_Vissage_M8_angle_value                   0.113109
# OP090_SnapRingMidPointForce_val                0.346948
# OP070_V_2_torque_value                         1.000000
# Binar OP130_Resultat_Global_v                 -0.039752
#
#                                  Binar OP130_Resultat_Global_v
# OP070_V_1_angle_value                                -0.012793
# OP090_SnapRingPeakForce_value                        -0.007290
# OP070_V_2_angle_value                                -0.006342
# OP120_Rodage_I_mesure_value                           0.003763
# OP090_SnapRingFinalStroke_value                       0.015148
# OP110_Vissage_M8_torque_value                        -0.002984
# OP120_Rodage_U_mesure_value                          -0.010492
# OP070_V_1_torque_value                               -0.037438
# OP090_StartLinePeakForce_value                        0.010720
# OP110_Vissage_M8_angle_value                          0.005470
# OP090_SnapRingMidPointForce_val                       0.014273
# OP070_V_2_torque_value                               -0.039752
# Binar OP130_Resultat_Global_v                         1.000000

# %%
visualization.plot_corr(df_training_cleaned, width=15, height=15, 
                        print_value=False)

# %%
features_corr = \
        feature_engineering.get_features_correlated_to_target(
                df_training_cleaned, target_feature='Binar OP130_Resultat_Global_v')

features_corr[:12]
# Out:
# Binar OP130_Resultat_Global_v      1.00
# OP070_V_1_torque_value            -0.04
# OP070_V_2_torque_value            -0.04
# OP090_SnapRingFinalStroke_value    0.02
# OP070_V_1_angle_value             -0.01
# OP090_SnapRingPeakForce_value     -0.01
# OP070_V_2_angle_value             -0.01
# OP120_Rodage_U_mesure_value       -0.01
# OP090_StartLinePeakForce_value     0.01
# OP110_Vissage_M8_angle_value       0.01
# OP090_SnapRingMidPointForce_val    0.01
# OP120_Rodage_I_mesure_value        0.00
# Name: Binar OP130_Resultat_Global_v, dtype: float64

# %%
val = df_training_cleaned['Binar OP130_Resultat_Global_v'].values
np.count_nonzero(val == 1)
# Out:
# 305

# %% [markdown]
# ### nonnull

# %%
corrmatrix = df_training_nonull.corr()
corrmatrix
# Out:
#                                  OP070_V_1_angle_value  \
# OP070_V_1_angle_value                         1.000000
# OP090_SnapRingPeakForce_value                 0.017731
# OP070_V_2_angle_value                         0.206809
# OP120_Rodage_I_mesure_value                   0.015439
# OP090_SnapRingFinalStroke_value              -0.055870
# OP110_Vissage_M8_torque_value                -0.046554
# OP100_Capuchon_insertion_mesure              -0.024779
# OP120_Rodage_U_mesure_value                  -0.007551
# OP070_V_1_torque_value                        0.025981
# OP090_StartLinePeakForce_value                0.020144
# OP110_Vissage_M8_angle_value                  0.031252
# OP090_SnapRingMidPointForce_val              -0.004953
# OP070_V_2_torque_value                        0.067972
# Binar OP130_Resultat_Global_v                 0.000075
#
#                                  OP090_SnapRingPeakForce_value  \
# OP070_V_1_angle_value                                 0.017731
# OP090_SnapRingPeakForce_value                         1.000000
# OP070_V_2_angle_value                                -0.020173
# OP120_Rodage_I_mesure_value                           0.005835
# OP090_SnapRingFinalStroke_value                      -0.096732
# OP110_Vissage_M8_torque_value                        -0.009387
# OP100_Capuchon_insertion_mesure                      -0.193211
# OP120_Rodage_U_mesure_value                           0.041993
# OP070_V_1_torque_value                                0.349438
# OP090_StartLinePeakForce_value                        0.357971
# OP110_Vissage_M8_angle_value                          0.066512
# OP090_SnapRingMidPointForce_val                       0.286376
# OP070_V_2_torque_value                                0.349925
# Binar OP130_Resultat_Global_v                         0.001748
#
#                                  OP070_V_2_angle_value  \
# OP070_V_1_angle_value                         0.206809
# OP090_SnapRingPeakForce_value                -0.020173
# OP070_V_2_angle_value                         1.000000
# OP120_Rodage_I_mesure_value                   0.019047
# OP090_SnapRingFinalStroke_value              -0.019488
# OP110_Vissage_M8_torque_value                -0.048310
# OP100_Capuchon_insertion_mesure               0.005722
# OP120_Rodage_U_mesure_value                  -0.004269
# OP070_V_1_torque_value                       -0.009474
# OP090_StartLinePeakForce_value               -0.011685
# OP110_Vissage_M8_angle_value                  0.024902
# OP090_SnapRingMidPointForce_val              -0.022472
# OP070_V_2_torque_value                       -0.020695
# Binar OP130_Resultat_Global_v                -0.008721
#
#                                  OP120_Rodage_I_mesure_value  \
# OP070_V_1_angle_value                               0.015439
# OP090_SnapRingPeakForce_value                       0.005835
# OP070_V_2_angle_value                               0.019047
# OP120_Rodage_I_mesure_value                         1.000000
# OP090_SnapRingFinalStroke_value                     0.017408
# OP110_Vissage_M8_torque_value                      -0.008639
# OP100_Capuchon_insertion_mesure                     0.053972
# OP120_Rodage_U_mesure_value                        -0.031949
# OP070_V_1_torque_value                             -0.015440
# OP090_StartLinePeakForce_value                      0.012944
# OP110_Vissage_M8_angle_value                       -0.008336
# OP090_SnapRingMidPointForce_val                     0.015603
# OP070_V_2_torque_value                             -0.015335
# Binar OP130_Resultat_Global_v                       0.003798
#
#                                  OP090_SnapRingFinalStroke_value  \
# OP070_V_1_angle_value                                  -0.055870
# OP090_SnapRingPeakForce_value                          -0.096732
# OP070_V_2_angle_value                                  -0.019488
# OP120_Rodage_I_mesure_value                             0.017408
# OP090_SnapRingFinalStroke_value                         1.000000
# OP110_Vissage_M8_torque_value                           0.000402
# OP100_Capuchon_insertion_mesure                         0.307973
# OP120_Rodage_U_mesure_value                            -0.090466
# OP070_V_1_torque_value                                 -0.643631
# OP090_StartLinePeakForce_value                         -0.427980
# OP110_Vissage_M8_angle_value                           -0.119204
# OP090_SnapRingMidPointForce_val                        -0.199176
# OP070_V_2_torque_value                                 -0.648122
# Binar OP130_Resultat_Global_v                           0.014889
#
#                                  OP110_Vissage_M8_torque_value  \
# OP070_V_1_angle_value                                -0.046554
# OP090_SnapRingPeakForce_value                        -0.009387
# OP070_V_2_angle_value                                -0.048310
# OP120_Rodage_I_mesure_value                          -0.008639
# OP090_SnapRingFinalStroke_value                       0.000402
# OP110_Vissage_M8_torque_value                         1.000000
# OP100_Capuchon_insertion_mesure                      -0.023820
# OP120_Rodage_U_mesure_value                           0.001635
# OP070_V_1_torque_value                               -0.003357
# OP090_StartLinePeakForce_value                        0.012750
# OP110_Vissage_M8_angle_value                         -0.410296
# OP090_SnapRingMidPointForce_val                       0.007834
# OP070_V_2_torque_value                               -0.003253
# Binar OP130_Resultat_Global_v                        -0.007228
#
#                                  OP100_Capuchon_insertion_mesure  \
# OP070_V_1_angle_value                                  -0.024779
# OP090_SnapRingPeakForce_value                          -0.193211
# OP070_V_2_angle_value                                   0.005722
# OP120_Rodage_I_mesure_value                             0.053972
# OP090_SnapRingFinalStroke_value                         0.307973
# OP110_Vissage_M8_torque_value                          -0.023820
# OP100_Capuchon_insertion_mesure                         1.000000
# OP120_Rodage_U_mesure_value                            -0.087928
# OP070_V_1_torque_value                                 -0.522733
# OP090_StartLinePeakForce_value                         -0.209883
# OP110_Vissage_M8_angle_value                           -0.094913
# OP090_SnapRingMidPointForce_val                         0.016094
# OP070_V_2_torque_value                                 -0.532577
# Binar OP130_Resultat_Global_v                           0.032212
#
#                                  OP120_Rodage_U_mesure_value  \
# OP070_V_1_angle_value                              -0.007551
# OP090_SnapRingPeakForce_value                       0.041993
# OP070_V_2_angle_value                              -0.004269
# OP120_Rodage_I_mesure_value                        -0.031949
# OP090_SnapRingFinalStroke_value                    -0.090466
# OP110_Vissage_M8_torque_value                       0.001635
# OP100_Capuchon_insertion_mesure                    -0.087928
# OP120_Rodage_U_mesure_value                         1.000000
# OP070_V_1_torque_value                              0.133145
# OP090_StartLinePeakForce_value                      0.098468
# OP110_Vissage_M8_angle_value                        0.003058
# OP090_SnapRingMidPointForce_val                     0.048902
# OP070_V_2_torque_value                              0.134290
# Binar OP130_Resultat_Global_v                      -0.016968
#
#                                  OP070_V_1_torque_value  \
# OP070_V_1_angle_value                          0.025981
# OP090_SnapRingPeakForce_value                  0.349438
# OP070_V_2_angle_value                         -0.009474
# OP120_Rodage_I_mesure_value                   -0.015440
# OP090_SnapRingFinalStroke_value               -0.643631
# OP110_Vissage_M8_torque_value                 -0.003357
# OP100_Capuchon_insertion_mesure               -0.522733
# OP120_Rodage_U_mesure_value                    0.133145
# OP070_V_1_torque_value                         1.000000
# OP090_StartLinePeakForce_value                 0.642305
# OP110_Vissage_M8_angle_value                   0.181338
# OP090_SnapRingMidPointForce_val                0.331653
# OP070_V_2_torque_value                         0.961706
# Binar OP130_Resultat_Global_v                 -0.029617
#
#                                  OP090_StartLinePeakForce_value  \
# OP070_V_1_angle_value                                  0.020144
# OP090_SnapRingPeakForce_value                          0.357971
# OP070_V_2_angle_value                                 -0.011685
# OP120_Rodage_I_mesure_value                            0.012944
# OP090_SnapRingFinalStroke_value                       -0.427980
# OP110_Vissage_M8_torque_value                          0.012750
# OP100_Capuchon_insertion_mesure                       -0.209883
# OP120_Rodage_U_mesure_value                            0.098468
# OP070_V_1_torque_value                                 0.642305
# OP090_StartLinePeakForce_value                         1.000000
# OP110_Vissage_M8_angle_value                           0.106103
# OP090_SnapRingMidPointForce_val                        0.738526
# OP070_V_2_torque_value                                 0.643899
# Binar OP130_Resultat_Global_v                          0.018142
#
#                                  OP110_Vissage_M8_angle_value  \
# OP070_V_1_angle_value                                0.031252
# OP090_SnapRingPeakForce_value                        0.066512
# OP070_V_2_angle_value                                0.024902
# OP120_Rodage_I_mesure_value                         -0.008336
# OP090_SnapRingFinalStroke_value                     -0.119204
# OP110_Vissage_M8_torque_value                       -0.410296
# OP100_Capuchon_insertion_mesure                     -0.094913
# OP120_Rodage_U_mesure_value                          0.003058
# OP070_V_1_torque_value                               0.181338
# OP090_StartLinePeakForce_value                       0.106103
# OP110_Vissage_M8_angle_value                         1.000000
# OP090_SnapRingMidPointForce_val                      0.055990
# OP070_V_2_torque_value                               0.181353
# Binar OP130_Resultat_Global_v                        0.000223
#
#                                  OP090_SnapRingMidPointForce_val  \
# OP070_V_1_angle_value                                  -0.004953
# OP090_SnapRingPeakForce_value                           0.286376
# OP070_V_2_angle_value                                  -0.022472
# OP120_Rodage_I_mesure_value                             0.015603
# OP090_SnapRingFinalStroke_value                        -0.199176
# OP110_Vissage_M8_torque_value                           0.007834
# OP100_Capuchon_insertion_mesure                         0.016094
# OP120_Rodage_U_mesure_value                             0.048902
# OP070_V_1_torque_value                                  0.331653
# OP090_StartLinePeakForce_value                          0.738526
# OP110_Vissage_M8_angle_value                            0.055990
# OP090_SnapRingMidPointForce_val                         1.000000
# OP070_V_2_torque_value                                  0.332650
# Binar OP130_Resultat_Global_v                           0.026853
#
#                                  OP070_V_2_torque_value  \
# OP070_V_1_angle_value                          0.067972
# OP090_SnapRingPeakForce_value                  0.349925
# OP070_V_2_angle_value                         -0.020695
# OP120_Rodage_I_mesure_value                   -0.015335
# OP090_SnapRingFinalStroke_value               -0.648122
# OP110_Vissage_M8_torque_value                 -0.003253
# OP100_Capuchon_insertion_mesure               -0.532577
# OP120_Rodage_U_mesure_value                    0.134290
# OP070_V_1_torque_value                         0.961706
# OP090_StartLinePeakForce_value                 0.643899
# OP110_Vissage_M8_angle_value                   0.181353
# OP090_SnapRingMidPointForce_val                0.332650
# OP070_V_2_torque_value                         1.000000
# Binar OP130_Resultat_Global_v                 -0.033348
#
#                                  Binar OP130_Resultat_Global_v
# OP070_V_1_angle_value                                 0.000075
# OP090_SnapRingPeakForce_value                         0.001748
# OP070_V_2_angle_value                                -0.008721
# OP120_Rodage_I_mesure_value                           0.003798
# OP090_SnapRingFinalStroke_value                       0.014889
# OP110_Vissage_M8_torque_value                        -0.007228
# OP100_Capuchon_insertion_mesure                       0.032212
# OP120_Rodage_U_mesure_value                          -0.016968
# OP070_V_1_torque_value                               -0.029617
# OP090_StartLinePeakForce_value                        0.018142
# OP110_Vissage_M8_angle_value                          0.000223
# OP090_SnapRingMidPointForce_val                       0.026853
# OP070_V_2_torque_value                               -0.033348
# Binar OP130_Resultat_Global_v                         1.000000

# %%
visualization.plot_corr(df_training_nonull, width=15, height=15, 
                        print_value=False)

# %%
features_corr = \
        feature_engineering.get_features_correlated_to_target(
                df_training_nonull, target_feature='Binar OP130_Resultat_Global_v')

features_corr[:12]
# Out:
# Binar OP130_Resultat_Global_v      1.00
# OP100_Capuchon_insertion_mesure    0.03
# OP070_V_1_torque_value            -0.03
# OP090_SnapRingMidPointForce_val    0.03
# OP070_V_2_torque_value            -0.03
# OP120_Rodage_U_mesure_value       -0.02
# OP090_StartLinePeakForce_value     0.02
# OP070_V_2_angle_value             -0.01
# OP090_SnapRingFinalStroke_value    0.01
# OP110_Vissage_M8_torque_value     -0.01
# OP070_V_1_angle_value              0.00
# OP090_SnapRingPeakForce_value      0.00
# Name: Binar OP130_Resultat_Global_v, dtype: float64

# %%
val = df_training_nonull['Binar OP130_Resultat_Global_v'].values
np.count_nonzero(val == 1)
# Out:
# 195

# %% [markdown]
# ## visualization
